# %% [markdown]
# # Install & Import Library

# %% [markdown]
# ## Install

# %% [markdown]
# ### TensorFlow.js

# %%
# !pip install tensorflowjs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 1.5 MB/s eta 0:00:00
# Collecting flax>=0.6.2
#   Downloading flax-0.6.3-py3-none-any.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.4/197.4 KB 3.6 MB/s eta 0:00:00
# Collecting tensorflow-decision-forests>=1.0.1
#   Downloading tensorflow_decision_forests-1.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 54.6 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (3.19.6)
# Collecting tensorflow<3,>=2.10.0
#   Downloading tensorflow-2.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-hub<0.13,>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (0.12.0)
# Requirement already satisfied: six<2,>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (1.15.0)
# Requirement already satisfied: jax>=0.3.16 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (0.3.25)
# Collecting packaging~=20.9
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 KB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflowjs) (5.10.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (3.2.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (1.0.4)
# Collecting orbax
#   Downloading orbax-0.1.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 KB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (6.0)
# Collecting optax
#   Downloading optax-0.1.4-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.9/154.9 KB 12.0 MB/s eta 0:00:00
# Collecting tensorstore
#   Downloading tensorstore-0.1.30-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 16.4 MB/s eta 0:00:00
# Collecting rich>=11.1
#   Downloading rich-13.2.0-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (4.4.0)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.8/dist-packages (from flax>=0.6.2->tensorflowjs) (1.21.6)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib_resources>=5.9.0->tensorflowjs) (3.11.0)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.8/dist-packages (from jax>=0.3.16->tensorflowjs) (1.7.3)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.8/dist-packages (from jax>=0.3.16->tensorflowjs) (3.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging~=20.9->tensorflowjs) (3.0.9)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 KB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.29.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (2.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.4.0)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.1.21-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.51.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (3.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.3.0)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 65.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (57.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow<3,>=2.10.0->tensorflowjs) (15.0.6.1)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 79.3 MB/s eta 0:00:00
# Collecting wurlitzer
#   Downloading wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from tensorflow-decision-forests>=1.0.1->tensorflowjs) (0.38.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from tensorflow-decision-forests>=1.0.1->tensorflowjs) (1.3.5)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from rich>=11.1->flax>=0.6.2->tensorflowjs) (2.6.1)
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (2.25.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax>=0.6.2->tensorflowjs) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax>=0.6.2->tensorflowjs) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->flax>=0.6.2->tensorflowjs) (0.11.0)
# Collecting chex>=0.1.5
#   Downloading chex-0.1.5-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 KB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.8/dist-packages (from optax->flax>=0.6.2->tensorflowjs) (0.3.25+cuda11.cudnn805)
# Collecting cached_property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: etils in /usr/local/lib/python3.8/dist-packages (from orbax->flax>=0.6.2->tensorflowjs) (1.0.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.8/dist-packages (from orbax->flax>=0.6.2->tensorflowjs) (3.6.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->tensorflow-decision-forests>=1.0.1->tensorflowjs) (2022.7)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from chex>=0.1.5->optax->flax>=0.6.2->tensorflowjs) (0.12.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.8/dist-packages (from chex>=0.1.5->optax->flax>=0.6.2->tensorflowjs) (0.1.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (5.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (6.0.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (4.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from pytest->orbax->flax>=0.6.2->tensorflowjs) (22.2.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.8/dist-packages (from pytest->orbax->flax>=0.6.2->tensorflowjs) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from pytest->orbax->flax>=0.6.2->tensorflowjs) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest->orbax->flax>=0.6.2->tensorflowjs) (9.0.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.8/dist-packages (from pytest->orbax->flax>=0.6.2->tensorflowjs) (1.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<3,>=2.10.0->tensorflowjs) (3.2.2)
# Installing collected packages: flatbuffers, cached_property, wurlitzer, tensorstore, tensorflow-estimator, packaging, mdurl, keras, markdown-it-py, rich, chex, tensorboard, optax, tensorflow, tensorflow-decision-forests, orbax, flax, tensorflowjs
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# Successfully installed cached_property-1.5.2 chex-0.1.5 flatbuffers-23.1.21 flax-0.6.3 keras-2.11.0 markdown-it-py-2.1.0 mdurl-0.1.2 optax-0.1.4 orbax-0.1.0 packaging-20.9 rich-13.2.0 tensorboard-2.11.2 tensorflow-2.11.0 tensorflow-decision-forests-1.2.0 tensorflow-estimator-2.11.0 tensorflowjs-4.2.0 tensorstore-0.1.30 wurlitzer-3.0.3

# %% [markdown]
# ### Kaggle

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.8/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.25.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle) (7.0.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (4.0.0)

# %% [markdown]
# ## Import

# %%
import os
import shutil
import zipfile
import pathlib

import numpy as np
import tensorflow as tf

from matplotlib import pyplot as plt

# %%
print(f'Tensorflow version: {tf.__version__}')
# Out:
# Tensorflow version: 2.11.0

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data Collecting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir ~/.kaggle

# %%
# !cp /content/drive/MyDrive/Skripsi/kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download virgiawan/12-classes-garbage-classification
# Out:
# Downloading 12-classes-garbage-classification.zip to /content
#  99% 80.0M/80.6M [00:04<00:00, 26.0MB/s]
# 100% 80.6M/80.6M [00:04<00:00, 21.0MB/s]

# %%
local_zip = '/content/12-classes-garbage-classification.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content/')
zip_ref.close()

# %%
PATH = '/content/garbage_classification'
PATH
# Out:
# '/content/garbage_classification'

# %%
data_dir = pathlib.Path(PATH)

image_count = len(list(data_dir.glob('*/*.jpg')))
print(f'Total image from this datasets : {image_count}')

print(f'\nDistribution Image')
for i, label in enumerate(os.listdir(data_dir)):
  label_dir = os.path.join(data_dir, label)
  len_label_dir = len(os.listdir(label_dir))
  print(f'{i+1}. {label} : {len_label_dir}')
# Out:
# Total image from this datasets : 7692
#
# Distribution Image
# 1. clothes : 645
# 2. brown-glass : 607
# 3. green-glass : 629
# 4. paper : 645
# 5. plastic : 645
# 6. shoes : 647
# 7. cardboard : 643
# 8. battery : 642
# 9. biological : 648
# 10. metal : 649
# 11. trash : 647
# 12. white-glass : 645

# %% [markdown]
# ## Data Preprocessing & Transformation

# %% [markdown]
# ### Set up Paramters

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)

np.random.seed(123)
seed = np.random.randint(0,100)
print(f"Current seed : {seed}")
# Out:
# Current seed : 66

# %% [markdown]
# ### Load data using a Keras utility

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=seed,
  image_size=IMG_SIZE,
  batch_size=BATCH_SIZE)

val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=seed,
  image_size=IMG_SIZE,
  batch_size=BATCH_SIZE)
# Out:
# Found 7692 files belonging to 12 classes.
# Using 6154 files for training.
# Found 7692 files belonging to 12 classes.
# Using 1538 files for validation.

# %%
class_names = train_ds.class_names
class_names_val = val_ds.class_names

print(f'List label Train data: \n{class_names}\n')
print(f'List label Validation data: \n{class_names_val}')
# Out:
# List label Train data:
# ['battery', 'biological', 'brown-glass', 'cardboard', 'clothes', 'green-glass', 'metal', 'paper', 'plastic', 'shoes', 'trash', 'white-glass']
#
# List label Validation data:
# ['battery', 'biological', 'brown-glass', 'cardboard', 'clothes', 'green-glass', 'metal', 'paper', 'plastic', 'shoes', 'trash', 'white-glass']

# %% [markdown]
# ### Check Image batch

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)

# %% [markdown]
# ### Plot Data

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Split Validation data to Test data

# %%
val_batches = tf.data.experimental.cardinality(val_ds)
test_dataset = val_ds.take(val_batches // 5)
val_ds = val_ds.skip(val_batches // 5)

print('Number of validation batches: %d' % tf.data.experimental.cardinality(val_ds))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches: 40
# Number of test batches: 9

# %% [markdown]
# ### Configure data performance for Training

# %%
AUTOTUNE = tf.data.AUTOTUNE

# train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
# val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

train_ds = train_ds.cache().shuffle(image_count//4).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #Create Layer & Model

# %% [markdown]
# ##Layer

# %% [markdown]
# ###Data Augmentation Layer

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2)],
  name="data_augmentation")

# %%
for image, _ in train_ds.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f62906013a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f6290575430> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# ### Rescale pixel Layer

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %% [markdown]
# ### Global Average Layer

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

# %% [markdown]
# ### Base Model Layer

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step

# %% [markdown]
# ### Freeze Base Model

# %%
base_model.trainable = False

# %% [markdown]
# ### Input Layer

# %%
inputs = tf.keras.Input(shape=IMG_SIZE + (3,))

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Builder

# %%
def model_builder():

  # Number Classes from data
  num_classes = len(class_names)

  # Create Model Sequential keras
  model = tf.keras.Sequential()

  # Add Custom Layer
  model.add(inputs)
  model.add(data_augmentation)
  model.add(normalization_layer)
  model.add(base_model)
  model.add(global_average_layer)

  # Add fully connected layer with dropout
  model.add(tf.keras.layers.Dense(units=512, activation="relu"))
  model.add(tf.keras.layers.Dropout(0.2))

  # Prediction Layer
  model.add(tf.keras.layers.Dense(num_classes, 
                                  activation='softmax', 
                                  name="final_output"))

  base_learning_rate = 1e-3
  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

  return model

# %% [markdown]
# # Train, Eval, & Test Model

# %% [markdown]
# ## Train

# %% [markdown]
# ### Define Callbacks

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint("checkpoint_model.h5", 
                                                      monitor="val_accuracy",
                                                      save_best_only=True,
                                                      verbose=1)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", 
                                                  patience=10, 
                                                  mode ="max", 
                                                  verbose=2, 
                                                  restore_best_weights=True)

# %% [markdown]
# ### Checking Model

# %%
model = model_builder()
print(f"Model : {model}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model : <keras.engine.sequential.Sequential object at 0x7f62939d80d0>

# %% [markdown]
# ### Model Training

# %%
history = model.fit(train_ds,
                    epochs=100,
                    validation_data=val_ds,
                    callbacks=[model_checkpoint, early_stopping])
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 193/193 [==============================] - ETA: 0s - loss: 0.7949 - accuracy: 0.7502
# Epoch 1: val_accuracy improved from -inf to 0.86640, saving model to checkpoint_model.h5
# 193/193 [==============================] - 52s 175ms/step - loss: 0.7949 - accuracy: 0.7502 - val_loss: 0.3866 - val_accuracy: 0.8664
# Epoch 2/100
# 193/193 [==============================] - ETA: 0s - loss: 0.4810 - accuracy: 0.8445
# Epoch 2: val_accuracy improved from 0.86640 to 0.88080, saving model to checkpoint_model.h5
# 193/193 [==============================] - 31s 163ms/step - loss: 0.4810 - accuracy: 0.8445 - val_loss: 0.3531 - val_accuracy: 0.8808
# Epoch 3/100
# 193/193 [==============================] - ETA: 0s - loss: 0.3981 - accuracy: 0.8710
# Epoch 3: val_accuracy improved from 0.88080 to 0.88880, saving model to checkpoint_model.h5
# 193/193 [==============================] - 34s 175ms/step - loss: 0.3981 - accuracy: 0.8710 - val_loss: 0.3133 - val_accuracy: 0.8888
# Epoch 4/100
# 193/193 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8778
# Epoch 4: val_accuracy improved from 0.88880 to 0.89600, saving model to checkpoint_model.h5
# 193/193 [==============================] - 35s 180ms/step - loss: 0.3649 - accuracy: 0.8778 - val_loss: 0.3068 - val_accuracy: 0.8960
# Epoch 5/100
# 193/193 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.8924
# Epoch 5: val_accuracy improved from 0.89600 to 0.89680, saving model to checkpoint_model.h5
# 193/193 [==============================] - 36s 188ms/step - loss: 0.3174 - accuracy: 0.8924 - val_loss: 0.2918 - val_accuracy: 0.8968
# Epoch 6/100
# 193/193 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.9019
# Epoch 6: val_accuracy improved from 0.89680 to 0.90480, saving model to checkpoint_model.h5
# 193/193 [==============================] - 48s 248ms/step - loss: 0.2888 - accuracy: 0.9019 - val_loss: 0.2951 - val_accuracy: 0.9048
# Epoch 7/100
# 193/193 [==============================] - ETA: 0s - loss: 0.2636 - accuracy: 0.9105
# Epoch 7: val_accuracy did not improve from 0.90480
# 193/193 [==============================] - 32s 166ms/step - loss: 0.2636 - accuracy: 0.9105 - val_loss: 0.3277 - val_accuracy: 0.8944
# Epoch 8/100
# 193/193 [==============================] - ETA: 0s - loss: 0.2310 - accuracy: 0.9248
# Epoch 8: val_accuracy improved from 0.90480 to 0.90560, saving model to checkpoint_model.h5
# 193/193 [==============================] - 31s 162ms/step - loss: 0.2310 - accuracy: 0.9248 - val_loss: 0.2829 - val_accuracy: 0.9056
# Epoch 9/100
# 193/193 [==============================] - ETA: 0s - loss: 0.2320 - accuracy: 0.9230
# Epoch 9: val_accuracy did not improve from 0.90560
# 193/193 [==============================] - 32s 163ms/step - loss: 0.2320 - accuracy: 0.9230 - val_loss: 0.2971 - val_accuracy: 0.8920
# Epoch 10/100
# 193/193 [==============================] - ETA: 0s - loss: 0.2073 - accuracy: 0.9288
# Epoch 10: val_accuracy did not improve from 0.90560
# 193/193 [==============================] - 31s 158ms/step - loss: 0.2073 - accuracy: 0.9288 - val_loss: 0.2763 - val_accuracy: 0.9056
# Epoch 11/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9353
# Epoch 11: val_accuracy did not improve from 0.90560
# 193/193 [==============================] - 33s 169ms/step - loss: 0.1897 - accuracy: 0.9353 - val_loss: 0.2773 - val_accuracy: 0.8976
# Epoch 12/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9361
# Epoch 12: val_accuracy did not improve from 0.90560
# 193/193 [==============================] - 34s 174ms/step - loss: 0.1878 - accuracy: 0.9361 - val_loss: 0.2959 - val_accuracy: 0.8960
# Epoch 13/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9371
# Epoch 13: val_accuracy did not improve from 0.90560
# 193/193 [==============================] - 31s 160ms/step - loss: 0.1777 - accuracy: 0.9371 - val_loss: 0.2902 - val_accuracy: 0.9032
# Epoch 14/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1621 - accuracy: 0.9428
# Epoch 14: val_accuracy did not improve from 0.90560
# 193/193 [==============================] - 31s 160ms/step - loss: 0.1621 - accuracy: 0.9428 - val_loss: 0.2839 - val_accuracy: 0.9024
# Epoch 15/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 0.9394
# Epoch 15: val_accuracy improved from 0.90560 to 0.90880, saving model to checkpoint_model.h5
# 193/193 [==============================] - 31s 163ms/step - loss: 0.1666 - accuracy: 0.9394 - val_loss: 0.2817 - val_accuracy: 0.9088
# Epoch 16/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9464
# Epoch 16: val_accuracy improved from 0.90880 to 0.90960, saving model to checkpoint_model.h5
# 193/193 [==============================] - 31s 161ms/step - loss: 0.1517 - accuracy: 0.9464 - val_loss: 0.2745 - val_accuracy: 0.9096
# Epoch 17/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9472
# Epoch 17: val_accuracy improved from 0.90960 to 0.91120, saving model to checkpoint_model.h5
# 193/193 [==============================] - 31s 162ms/step - loss: 0.1442 - accuracy: 0.9472 - val_loss: 0.2601 - val_accuracy: 0.9112
# Epoch 18/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1509 - accuracy: 0.9428
# Epoch 18: val_accuracy did not improve from 0.91120
# 193/193 [==============================] - 31s 160ms/step - loss: 0.1509 - accuracy: 0.9428 - val_loss: 0.2707 - val_accuracy: 0.9072
# Epoch 19/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1417 - accuracy: 0.9516
# Epoch 19: val_accuracy did not improve from 0.91120
# 193/193 [==============================] - 31s 161ms/step - loss: 0.1417 - accuracy: 0.9516 - val_loss: 0.2791 - val_accuracy: 0.9088
# Epoch 20/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1331 - accuracy: 0.9548
# Epoch 20: val_accuracy did not improve from 0.91120
# 193/193 [==============================] - 36s 187ms/step - loss: 0.1331 - accuracy: 0.9548 - val_loss: 0.2930 - val_accuracy: 0.9048
# Epoch 21/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1330 - accuracy: 0.9535
# Epoch 21: val_accuracy did not improve from 0.91120
# 193/193 [==============================] - 31s 159ms/step - loss: 0.1330 - accuracy: 0.9535 - val_loss: 0.3207 - val_accuracy: 0.9104
# Epoch 22/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9613
# Epoch 22: val_accuracy did not improve from 0.91120
# 193/193 [==============================] - 31s 159ms/step - loss: 0.1070 - accuracy: 0.9613 - val_loss: 0.3163 - val_accuracy: 0.9080
# Epoch 23/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1150 - accuracy: 0.9618
# Epoch 23: val_accuracy did not improve from 0.91120
# 193/193 [==============================] - 31s 160ms/step - loss: 0.1150 - accuracy: 0.9618 - val_loss: 0.3158 - val_accuracy: 0.9080
# Epoch 24/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.9597
# Epoch 24: val_accuracy did not improve from 0.91120
# 193/193 [==============================] - 31s 160ms/step - loss: 0.1101 - accuracy: 0.9597 - val_loss: 0.3133 - val_accuracy: 0.9064
# Epoch 25/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9612
# Epoch 25: val_accuracy improved from 0.91120 to 0.91360, saving model to checkpoint_model.h5
# 193/193 [==============================] - 31s 161ms/step - loss: 0.1169 - accuracy: 0.9612 - val_loss: 0.2777 - val_accuracy: 0.9136
# Epoch 26/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9576
# Epoch 26: val_accuracy did not improve from 0.91360
# 193/193 [==============================] - 31s 161ms/step - loss: 0.1221 - accuracy: 0.9576 - val_loss: 0.3480 - val_accuracy: 0.9024
# Epoch 27/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9610
# Epoch 27: val_accuracy improved from 0.91360 to 0.91600, saving model to checkpoint_model.h5
# 193/193 [==============================] - 37s 190ms/step - loss: 0.1219 - accuracy: 0.9610 - val_loss: 0.2972 - val_accuracy: 0.9160
# Epoch 28/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9618
# Epoch 28: val_accuracy improved from 0.91600 to 0.92320, saving model to checkpoint_model.h5
# 193/193 [==============================] - 31s 159ms/step - loss: 0.1046 - accuracy: 0.9618 - val_loss: 0.2785 - val_accuracy: 0.9232
# Epoch 29/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0998 - accuracy: 0.9634
# Epoch 29: val_accuracy did not improve from 0.92320
# 193/193 [==============================] - 31s 159ms/step - loss: 0.0998 - accuracy: 0.9634 - val_loss: 0.2579 - val_accuracy: 0.9232
# Epoch 30/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9691
# Epoch 30: val_accuracy improved from 0.92320 to 0.92400, saving model to checkpoint_model.h5
# 193/193 [==============================] - 31s 159ms/step - loss: 0.0922 - accuracy: 0.9691 - val_loss: 0.2538 - val_accuracy: 0.9240
# Epoch 31/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9639
# Epoch 31: val_accuracy did not improve from 0.92400
# 193/193 [==============================] - 31s 161ms/step - loss: 0.0990 - accuracy: 0.9639 - val_loss: 0.3056 - val_accuracy: 0.9056
# Epoch 32/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1054 - accuracy: 0.9657
# Epoch 32: val_accuracy did not improve from 0.92400
# 193/193 [==============================] - 31s 158ms/step - loss: 0.1054 - accuracy: 0.9657 - val_loss: 0.2738 - val_accuracy: 0.9208
# Epoch 33/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9716
# Epoch 33: val_accuracy did not improve from 0.92400
# 193/193 [==============================] - 31s 158ms/step - loss: 0.0916 - accuracy: 0.9716 - val_loss: 0.3117 - val_accuracy: 0.9200
# Epoch 34/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9651
# Epoch 34: val_accuracy did not improve from 0.92400
# 193/193 [==============================] - 36s 189ms/step - loss: 0.0918 - accuracy: 0.9651 - val_loss: 0.2931 - val_accuracy: 0.9048
# Epoch 35/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9716
# Epoch 35: val_accuracy did not improve from 0.92400
# 193/193 [==============================] - 30s 157ms/step - loss: 0.0756 - accuracy: 0.9716 - val_loss: 0.3823 - val_accuracy: 0.8904
# Epoch 36/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9677
# Epoch 36: val_accuracy did not improve from 0.92400
# 193/193 [==============================] - 31s 159ms/step - loss: 0.0921 - accuracy: 0.9677 - val_loss: 0.3068 - val_accuracy: 0.9136
# Epoch 37/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9708
# Epoch 37: val_accuracy did not improve from 0.92400
# 193/193 [==============================] - 30s 157ms/step - loss: 0.0849 - accuracy: 0.9708 - val_loss: 0.3141 - val_accuracy: 0.9192
# Epoch 38/100
# 193/193 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9633
# Epoch 38: val_accuracy did not improve from 0.92400
# 193/193 [==============================] - 31s 159ms/step - loss: 0.1040 - accuracy: 0.9633 - val_loss: 0.3511 - val_accuracy: 0.9056
# Epoch 39/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0851 - accuracy: 0.9706
# Epoch 39: val_accuracy did not improve from 0.92400
# 193/193 [==============================] - 30s 157ms/step - loss: 0.0851 - accuracy: 0.9706 - val_loss: 0.3430 - val_accuracy: 0.9120
# Epoch 40/100
# 193/193 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9691
# Epoch 40: val_accuracy did not improve from 0.92400
# Restoring model weights from the end of the best epoch: 30.
# 193/193 [==============================] - 31s 159ms/step - loss: 0.0914 - accuracy: 0.9691 - val_loss: 0.3227 - val_accuracy: 0.9104
# Epoch 40: early stopping

# %% [markdown]
# ## Eval

# %% [markdown]
# ### Plot Result

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ### Evaluate Model Performance

# %%
load_model = tf.keras.models.load_model('checkpoint_model.h5')
load_model.evaluate(x=test_dataset, return_dict=True)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 9/9 [==============================] - 1s 52ms/step - loss: 0.2819 - accuracy: 0.9444
# {'loss': 0.28190484642982483, 'accuracy': 0.9444444179534912}

# %% [markdown]
# ## Test

# %% [markdown]
# ### Change format to ndarray

# %%
class_names = np.array(class_names)
class_names_val = np.array(class_names_val)

print(f'List label Train data: \n{class_names}\n')
print(f'List label Validation data: \n{class_names_val}')
# Out:
# List label Train data:
# ['battery' 'biological' 'brown-glass' 'cardboard' 'clothes' 'green-glass'
#  'metal' 'paper' 'plastic' 'shoes' 'trash' 'white-glass']
#
# List label Validation data:
# ['battery' 'biological' 'brown-glass' 'cardboard' 'clothes' 'green-glass'
#  'metal' 'paper' 'plastic' 'shoes' 'trash' 'white-glass']

# %%
image_batch_test, label_batch_test = next(iter(test_dataset))

image_batch_test, label_batch_test = image_batch_test.numpy(), label_batch_test.numpy()


predicted_batch = load_model.predict(image_batch_test)
predicted_batch = tf.squeeze(predicted_batch).numpy()

predicted_ids = np.argmax(predicted_batch, axis=-1)
predicted_class_names = class_names[predicted_ids]

print(predicted_class_names)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# ['battery' 'paper' 'trash' 'shoes' 'paper' 'shoes' 'clothes' 'brown-glass'
#  'white-glass' 'metal' 'battery' 'brown-glass' 'white-glass' 'clothes'
#  'brown-glass' 'white-glass' 'white-glass' 'shoes' 'brown-glass' 'clothes'
#  'green-glass' 'clothes' 'biological' 'biological' 'trash' 'green-glass'
#  'shoes' 'metal' 'clothes' 'paper' 'cardboard' 'cardboard']

# %%
print(f"Labels:\n{label_batch_test}")
print(f"Predicted labels:\n{predicted_ids}")

true_predict = 0
false_predict = 0

for i in predicted_ids:
  if i in label_batch_test:
    true_predict +=1
  else:
    false_predict +=1

print()
print(f'True Predict Count : {true_predict}')
print(f'False Predict Count : {false_predict}')
# Out:
# Labels:
# [ 0  7 10  9  7  9  4  2 11  6  0  2 11  4  5 11 11  9  2  4  5  4  1  1
#  10  5  9  6  4  7  7  7]
# Predicted labels:
# [ 0  7 10  9  7  9  4  2 11  6  0  2 11  4  2 11 11  9  2  4  5  4  1  1
#  10  5  9  6  4  7  3  3]
#
# True Predict Count : 30
# False Predict Count : 2

# %%
plt.figure(figsize=(15,10))
plt.subplots_adjust(hspace=0.3)

for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch_test[n].astype('uint8'))
  color = "blue" if predicted_ids[n] == label_batch_test[n] else "red"
  plt.title(predicted_class_names[n].title(), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions")

# %%
# from google.colab import files
# import keras.utils as image

# uploaded = files.upload()

# for fn in uploaded.keys():
 
#   # predicting images
#   path = fn
#   img = image.load_img(path, target_size= IMG_SIZE + (3,))
#   x = image.img_to_array(img)
#   x = np.expand_dims(x, axis=0)

#   images = np.vstack([x])
#   classes = load_model.predict(images, batch_size=10)
#   outclass = np.argmax(classes)
  
#   print(fn)
#   plt.imshow(img)
#   for i, label in enumerate(class_names):
#     if outclass == i:
#       predict = classes[0][i]
#       print(label)
#       print(classes)
#       print(predict)

# %% [markdown]
# # Save & Convert Model

# %% [markdown]
# ## Save Model to Saved Model Format

# %%
path_model = './saved'
output_path = '/content/output_path'
load_model.save(path_model)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:absl:Found untraced functions such as _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.

# %%
path_model=pathlib.Path(path_model)

# %% [markdown]
# ## Convert Saved Model into JSON Format

# %%
# !tensorflowjs_converter --input_format=tf_saved_model \
                         --output_node_names='MobilenetV3/Predictions/Reshape_1' \
                         --saved_model_tags=serve \
                         './saved' \
                         output_path
# Out:
# 2023-01-26 07:06:37.249458: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-26 07:06:37.249588: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-01-26 07:06:37.249607: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-01-26 07:06:41.233680: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Writing weight file output_path/model.json...

# %% [markdown]
# ## Archive Model

# %%
shutil.make_archive('/content/json', 'zip', output_path)
# Out:
# '/content/json.zip'

# %% [markdown]
# ## Download Model

# %%
from google.colab import files

# %%
checkpoint_model_path = './checkpoint_model.h5'
checkpoint_model_path = pathlib.Path(checkpoint_model_path)

# %%
files.download('/content/json.zip')
files.download(checkpoint_model_path)
